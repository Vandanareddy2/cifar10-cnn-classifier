# %% [markdown]
# <a href="https://colab.research.google.com/github/Vandanareddy2/cifar10-cnn-classifier/blob/main/cifar10_exp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Vandanareddy2/cifar10-cnn-classifier.git
# %cd cifar10-cnn-classifier
# Out:
# Cloning into 'cifar10-cnn-classifier'...
# remote: Enumerating objects: 28, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 28 (delta 10), reused 20 (delta 6), pack-reused 0 (from 0)
# Receiving objects: 100% (28/28), 5.62 KiB | 2.81 MiB/s, done.
# Resolving deltas: 100% (10/10), done.
# /content/cifar10-cnn-classifier/cifar10-cnn-classifier

# %%
# !ls
# Out:
# data  LICENSE  notebooks  README.md  src

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# Tesla T4

# %%
# !ls /content/cifar10-cnn-classifier/notebooks/

# %%
# !cp /content/drive/MyDrive/*.ipynb /content/cifar10-cnn-classifier/notebooks/
# Out:
# cp: cannot stat '/content/drive/MyDrive/*.ipynb': No such file or directory
